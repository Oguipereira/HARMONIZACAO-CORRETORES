# %% [markdown]
# <a href="https://colab.research.google.com/github/Oguipereira/HARMONIZACAO-CORRETORES/blob/main/harmoniza%C3%A7%C3%A3o_de_corretores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Código inicial de harmonização de carteira

# %%
#clonando repositorio
# !git clone https://github.com/Oguipereira/HARMONIZACAO-CORRETORES.git
# Out:
# Cloning into 'HARMONIZACAO-CORRETORES'...
# ...

# %%
#Entrar na pasta
# %cd HARMONIZACAO-CORRETORES
# Out:
# /content/HARMONIZACAO-CORRETORES/HARMONIZACAO-CORRETORES/HARMONIZACAO-CORRETORES

# %%
# %%writefile config.py
from pathlib import Path

BASE_DIR = Path.cwd()

DADOS_DIR = BASE_DIR / "dados"
OUTPUT_DIR = BASE_DIR / "output"

# restante do seu config.py aqui...
# Out:
# Writing config.py

# %%
#instalando dependencias
# !pip install pandas openpyxl pyxlsb numpy

# %%
#estrutura de pastas
import os

os.makedirs("dados", exist_ok=True)
os.makedirs("output", exist_ok=True)

print("Pastas criadas.")
# Out:
# Pastas criadas.

# %%
#Upload dos arquivos Excel
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-69167375-0291-428c-bfb3-deb1a54428ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69167375-0291-428c-bfb3-deb1a54428ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#mover arquivos para analise de dados
import shutil

for arquivo in uploaded.keys():
    shutil.move(arquivo, f"dados/{arquivo}")

print("Arquivos movidos.")

# %%
#verificação de dados
import os

print("DADOS")

for arquivo in os.listdir("dados"):
    print(arquivo)

# %%
from pathlib import Path
import config

config.BASE_DIR = Path.cwd()
config.DADOS_DIR = config.BASE_DIR / "dados"
config.OUTPUT_DIR = config.BASE_DIR / "output"

print(config.BASE_DIR)

# %%
#executando...
import builtins
respostas =iter([
    "SIM",
    "APLICAR"
])

builtins.input = lambda _: next(respostas)

import main

main.main()

# %%
#baixar resultados
from google.colab import files
import os

for arquivo in os.listdir("output"):
    files.download(f"output/{arquivo}")
